# %%
import numpy as np
import  pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
titanic=pd.read_csv('titanic-training-data.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 78            79         1       2
# 846          847         0       3
# 477          478         0       3
# 425          426         0       3
# 167          168         0       3
# 707          708         1       1
# 423          424         0       3
# 841          842         0       2
# 456          457         0       1
# 270          271         0       1
#
#                                                   Name     Sex    Age  SibSp  \
# 78                       Caldwell, Master. Alden Gates    male   0.83      0
# 846                           Sage, Mr. Douglas Bullen    male    NaN      8
# 477                          Braund, Mr. Lewis Richard    male  29.00      1
# 425                             Wiseman, Mr. Phillippe    male    NaN      0
# 167    Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.00      1
# 707                  Calderhead, Mr. Edward Pennington    male  42.00      0
# ...

# %%
sns.countplot(x="Pclass",data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="Sex",data=titanic)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#countplot is for the categorical plot 
sns.countplot(x="Embarked",data=titanic)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x="Pclass",hue="Sex",data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="Pclass",hue="Embarked",data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="Embarked",hue="Sex",data=titanic)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Counterplot

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
sns.countplot(x="Sex",data=titanic)
plt.show()

# %%
#perameter for another categorical 
sns.countplot(x="Embarked",hue="Sex",data=titanic)
plt.show()

# %%
sns.countplot(x="Embarked",hue="Pclass",data=titanic)
plt.show()

# %%
sns.countplot(x="Pclass",hue="Sex",data=titanic)
plt.show()

# %%
sns.distplot(titanic["Age"],hist=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
#swarmplot is  use for deealing with the categorical and numerical values
sns.swarmplot(x="Pclass",y='Fare',data=titanic)
plt.show()

# %%
sns.violinplot(x="Pclass",y='Fare',data=titanic)
plt.show()

# %%
sns.violinplot(x="Pclass",y='Age',data=titanic)
plt.show()

# %%
sns.violinplot(x="Sex",y='Fare',data=titanic)
plt.show()

# %%
sns.violinplot(x="Embarked",y='Age',data=titanic)
plt.show()

# %% [markdown]
# # BIVARIATE->Twi numerical

# %%
sns.scatterplot(x="Age",y="Fare",data=titanic)
plt.show()

# %% [markdown]
# # sns.pairplot(titanic)

# %%
sns.pairplot(titanic)

# %% [markdown]
# # outliear

# %%
sns.boxplot(x=titanic["Age"])
plt.show()

# %%
sns.boxplot(x=titanic["Fare"])
plt.show()

# %%
corr_matrix =titanic.corr()
sns.heatmap(corr_matrix,annot=True)
plt.show()

# %%
corr_matrix =titanic.corr()
sns.heatmap(corr_matrix,annot=True)
plt.show()
